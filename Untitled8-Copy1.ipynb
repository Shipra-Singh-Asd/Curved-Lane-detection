# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython.display import HTML, Video
from moviepy.editor import VideoFileClip
from PerspectiveTransformation import *
from LaneLines import *

# %%
images = []
images.append(mpimg.imread('challenge_video_frame_1.jpg'))
images.append(mpimg.imread('challenge_video_frame_100.jpg'))
images.append(mpimg.imread('challenge_video_frame_110.jpg'))
images.append(mpimg.imread('challenge_video_frame_120.jpg'))
images.append(mpimg.imread('challenge_video_frame_130.jpg'))
images.append(mpimg.imread('challenge_video_frame_140.jpg'))

# %%
images1 = []
images1.append(mpimg.imread('project_video_frame_1032.jpg'))
images1.append(mpimg.imread('project_video_frame_1048.jpg'))
images1.append(mpimg.imread('project_video_frame_235.jpg'))
images1.append(mpimg.imread('project_video_frame_810.jpg'))
images1.append(mpimg.imread('project_video_frame_551.jpg'))

# %%
images2 = []
images2.append(mpimg.imread('harder_challenge_video_frame_1.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_10.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_100.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_200.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_300.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_400.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_500.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_600.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_700.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_800.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_900.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_1000.jpg'))
images2.append(mpimg.imread('harder_challenge_video_frame_1100.jpg'))

# %%
def plot(img):
    hls = cv2.cvtColor(img, cv2.COLOR_RGB2HLS)
    f = plt.figure(figsize=(24, 9))
    ax1 = f.add_subplot(1, 3, 1)
    plt.title("Hue",fontsize = 14, fontweight ='bold')
    ax1.imshow(hls[:,:,0], cmap='gray', vmin=0, vmax=255)
    ax2 = f.add_subplot(1, 3, 2)
    plt.title("Lighteness",fontsize = 14, fontweight ='bold')
    ax2.imshow(hls[:,:,1], cmap='gray', vmin=0, vmax=255)
    ax3 = f.add_subplot(1, 3, 3)
    plt.title("Saturation",fontsize = 14, fontweight ='bold')
    ax3.imshow(hls[:,:,2], cmap='gray', vmin=0, vmax=255)
    plt.figure()
    plt.title("Original",fontsize = 14, fontweight ='bold')
    plt.imshow(img)

# %%
img = images2[2]
birdeye = PerspectiveTransformation()

# %%
plot(img)

# %%
def threshold_rel(img, lo, hi):
    vmin = np.min(img)
    vmax = np.max(img)
    
    vlo = vmin + (vmax - vmin) * lo
    vhi = vmin + (vmax - vmin) * hi
    return np.uint8((img >= vlo) & (img <= vhi)) * 255

def threshold_abs(img, lo, hi):
    return np.uint8((img >= lo) & (img <= hi)) * 255

# %%
def test(img):
    tmp = birdeye.forward(img)
    tmp = np.copy(img)
    hls = cv2.cvtColor(tmp, cv2.COLOR_RGB2HLS)
    hsv = cv2.cvtColor(tmp, cv2.COLOR_RGB2HSV)
    h_channel = hls[:,:,0]
    l_channel = hls[:,:,1]
    s_channel = hls[:,:,2]
    v_channel = hsv[:,:,2]
    
    f = plt.figure(figsize=(24, 16))
    ax1 = f.add_subplot(2, 2, 1)
    ax1.imshow(tmp)
    ax2 = f.add_subplot(2, 2, 2)
    ax2.imshow(threshold_rel(l_channel, 0.8, 1.0), vmin=0, vmax=255, cmap='gray')
    
    ax3 = f.add_subplot(2, 2, 3)
    ax3.imshow(threshold_rel(s_channel, 0.5, 0.8), vmin=0, vmax=255, cmap='gray')
    
    ax4 = f.add_subplot(2, 2, 4)
    res = threshold_abs(h_channel, 20, 30)
    res &= threshold_rel(v_channel, 0.7, 1.0)
    ax4.imshow(res, vmin=0, vmax=255, cmap='gray')

# %%
test(images2[2])

# %%
img = images2[1]
plt.imshow(img)

# %%
img1 = birdeye.forward(img)
plt.imshow(img1)
plt.title('Warped Image', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Warped Image')

# %%
hls = cv2.cvtColor(img1, cv2.COLOR_RGB2HLS)
hsv = cv2.cvtColor(img1, cv2.COLOR_RGB2HSV)
h_channel = hls[:,:,0]
l_channel = hls[:,:,1]
s_channel = hls[:,:,2]
v_channel = hsv[:,:,2]

f = plt.figure(figsize=(24, 16))
ax1 = f.add_subplot(2, 2, 1)
ax1.imshow(img1)
ax2 = f.add_subplot(2, 2, 2)
right_lane = threshold_rel(l_channel, 0.8, 1.0)
# right_lane[:,:750] = 0
ax2.imshow(right_lane, vmin=0, vmax=255, cmap='gray')

ax3 = f.add_subplot(2, 2, 3)
left_lane = threshold_abs(h_channel, 20, 30)
left_lane &= threshold_rel(v_channel, 0.7, 1.0)
left_lane[:,550:] = 0
ax3.imshow(left_lane, vmin=0, vmax=255, cmap='gray')

img2 = left_lane | right_lane
ax4 = f.add_subplot(2, 2, 4)
ax4.imshow(img2, vmin=0, vmax=255, cmap='gray')

# %%
lanelines = LaneLines()
img3 = lanelines.forward(img2)
plt.imshow(img3)
plt.title('Visualize the result of the lane detection.', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Visualize the result of the lane detection.')

# %%
img4 = birdeye.backward(img3)
out_img = cv2.addWeighted(img, 1, img4, 0.3, 0)
plt.imshow(out_img)

# %%
img4 = birdeye.backward(img3)
out_img = cv2.addWeighted(img, 1, img4, 0.3, 0)
out_img=lanelines.plot(out_img)
plt.imshow(out_img)

# %%
birdeye = PerspectiveTransformation()
lanelines = LaneLines()
def process_image(img):
    # step 1
    img1 = birdeye.forward(img)
#     img1 = np.copy(img)
    
    # step 2
    hls = cv2.cvtColor(img1, cv2.COLOR_RGB2HLS)
    hsv = cv2.cvtColor(img1, cv2.COLOR_RGB2HSV)
    h_channel = hls[:,:,0]
    l_channel = hls[:,:,1]
    s_channel = hls[:,:,2]
    v_channel = hsv[:,:,2]

    right_lane = threshold_rel(l_channel, 0.8, 1.0)
    right_lane[:,:750] = 0

    left_lane = threshold_abs(h_channel, 20, 30)
    left_lane &= threshold_rel(v_channel, 0.7, 1.0)
    left_lane[:,550:] = 0

    img2 = left_lane | right_lane
    
#     img2 = birdeye.forward(img2)
    
    # step 3
    img3 = lanelines.forward(img2)
    
    # step 4
    img4 = birdeye.backward(img3)
    out_img = cv2.addWeighted(img, 1, img4, 1, 0)
    #leftr,rightr,postt=lanelines.measure_curvature()
    #font = cv2.FONT_HERSHEY_SIMPLEX
    #fontSize=0.5
    #cv2.putText(out_img, 'Lane Curvature: {:.0f} m'.format(leftr), (100, 100), font, fontSize, fontColor, 2)
    #cv2.putText(out_img, 'Vehicle offset: {:.4f} m'.format(postt), (120, 120), font, fontSize, fontColor, 2)
    out_img=lanelines.plot(out_img)
    return out_img

# %%
clip = VideoFileClip("project_video.mp4")

# %%
out_clip = clip.fl_image(process_image)
out_clip.write_videofile("C:/Users/shipra singh/Desktop/tmp11.mp4", audio=False)
# Out:
# t:   0%|▏                                                                   | 3/1260 [00:00<01:14, 16.82it/s, now=None]
# Moviepy - Building video C:/Users/shipra singh/Desktop/tmp11.mp4.
# Moviepy - Writing video C:/Users/shipra singh/Desktop/tmp11.mp4
# Moviepy - Done !
# Moviepy - video ready C:/Users/shipra singh/Desktop/tmp11.mp4
